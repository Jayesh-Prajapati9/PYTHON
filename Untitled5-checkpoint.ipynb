# %%
days = int(input("Enter the number of days:- "))
year = days//365
days = days%365
months = days//30
days = days%30
print(f"{days}= {year} years,{months} months,{days} days")
# Out:
# Enter the number of days:- 125
# 5= 0 years,4 months,5 days

# %%
d=int(input("Enter The No of Days : "))
sum=0
m=1
week=7
s=d//7
for i in range(s):
    for j in range(m,week+1):
        sum+=j
    m+=1
    week+=1
for k in range(d%7):
    sum+=m
    m+=1

print(sum)
# Out:
# Enter The No of Days : 30
# 165

# %% [markdown]
# money=float(input("Enter : )
# if money>1

# %%
count=0
max=int(i**(1/3)+1)
for i in range (1720,10000):
    for j in range (1,max):
        for k in range (i,max):
            total=j**3+k**3
            if(total==i):
                print(i)
                count+=1
                if count==2:
                    print(i)
                    break

# %%
for i in range (1,6):
    for j in range(1,6):
        if(i==1 or i==5 or j==1 or j==5):
            print("*", end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
# * * * * *
# *       *
# *       *
# *       *
# * * * * *
