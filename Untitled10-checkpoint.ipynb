# %%
def pr(x): 
    global v 
    msg=str(v)  
    print(type(v))  
    v="hi"  
    print(v)  
global v  
v=6  
pr('u')
# Out:
# <class 'int'>
# hi

# %%
 
def g(): 
    print("li")

# %%
num=int(input("Enter Your Number : "))

def check(num):
    n=num
    n1=n%10
    n2=n//10
    newnum=(n1**2)+(n2**2)
    if(newnum==4):
        print("Not Happy")
        return
    if(newnum==1):
        print("Happy")
        return
    else:
        check(newnum)
check(num)
