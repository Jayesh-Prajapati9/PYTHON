# %%
num=int(input("Enter Your Number : "))

def check(num):
    n=num
    n1=n%10
    n2=n//10
    if(n2>=10):
        n3=n2%10
        n2=n2//10
        newnum=(n3**2)+(n1**2)+(n2**2)
    else:
        newnum=(n1**2)+(n2**2)
    if(newnum==4 or newnum==0):
        print("Not Happy")
        return
    if(newnum==1):
        print("Happy")
        return
    else:
        check(newnum)
check(num)

# %%
num=int(input("Enter The NUmber : "))
count=0
while(num>0):
    global count
    num=num%10
    count+=1
    num=num//10

# %%
num=int(input("Enter The Number : "))
for i in range(1,num+1):
    for j in range(i+1,num+1):
        for k in range(j+1,num+1):
            if((i**2)+(j**2)==(k**2)):
                print(i,j,k)
                break
