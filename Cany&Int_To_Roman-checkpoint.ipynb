# %%
rating= eval(input("Enter The List : "))
l=[1]*len(rating)

for i in range(1,len(rating)):
    if rating[i]>rating[i-1]:
        l[i]=l[i-1]+1
for i in range((len(rating))-2,-1,-1):
    if rating[i]>rating[i+1]:
        l[i]=max(l[i],(l[i+1]+1))
print(l)
print("Total Candies :
      
      
      a/cx  ",sum(l))
# Out:
# Enter The List : [8,3,2,1,8,3,2]
# [4, 3, 2, 1, 3, 2, 1]
# Total Candies :  16

# %%
msg=input("Enter The Message :")
key=int(input("Enter The Key :"))
encrpt=""
for i in range(key):
        encrpt+=msg[i::key]
print(encrpt)

l=[""]*len(msg)
count=0
for i in range(key):
    for j in range(i,len(encrpt),key):
        l[j]=encrpt[count]
        count+=1
print("".join(l))
# Out:
# Enter The Message :secret message
# Enter The Key :3
# sr sgeemsectea
# secret message

# %%
def findMedianSortedArrays(self, nums1, nums2):
        nums3=[]
        nums3=nums3.append(nums1)
        nums3=nums3.append(nums2)
        sorted(nums3)
        if(len(nums3)%2==0):
            n=len(nums3)/2
            n1=n+1
            return((nums3[n]+nums3[n1])/2)
        else:
            return(nums3[len(nums3)/2])
nums1=[1,3]
nums2=[2]
findMedianSortedArrays(nums1,nums2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-5958475a39b3> in <module>
#      12 nums1=[1,3]
#      13 nums2=[2]
# ---> 14 findMedianSortedArrays(nums1,nums2)
#
# TypeError: findMedianSortedArrays() missing 1 required positional argument: 'nums2'

# %%
def notowords(n):
    d={1:"ONE",2:"TWO",3:"THREE",4:"FOUR",5:"FIVE",6:"SIX",7:"SEVEN",8:"EIGHT",9:"NINE",10:"TEN",11:"ELEVEN",12:"TWELVE",13:"THIRTEN",
       14:"FOURTEEN",15:"FIFTEEN",16:"SIXTEEN",17:"SEVENTEEN",18:"EIGHTEEN",19:"NINTEEN",20:"TWENTY",30:"THIRTY",40:"FORTY",50:"FIFTY",60:"SIXTY",
       70:"SEVENTY",80:"EIGHTY",90:"NINTY"}
    if(n<10):
        return(d[n])
    elif(n<20):
        return(d[n])
    elif(n<100):
        return (d[(n//10)*10]+""+d[n%10])
    elif(n>100):
        return (notowords(n//100)+" HUNDRED "+notowords(n%100))

print(notowords(115))
# Out:
# ONE HUNDRED FIFTEEN
