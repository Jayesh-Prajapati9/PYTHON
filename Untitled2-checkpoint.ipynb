# %%
a=1 #Declaring a variable
b=2 #Declaring a variable
'''This is a program to print addition of 2 numbers'''
print(a+b)
# Out:
# 3

# %%
a,b,c,d=1,"Hi",2.5,True
print(f"{a},{b},{c},{d}")
# Out:
# 1,Hi,2.5,True

# %%
A = int(input("Enter a number:- "))
print(A)
print(type(A))
